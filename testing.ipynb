# %%
# !python --version
# Out:
# Python 3.12.3

# %%
# !git clone https://github.com/CHELSEA234/HiFi_IFDL.git
# %cd HiFi_IFDL

# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# !pip install kmeans-pytorch yacs
# Out:
# Cloning into 'HiFi_IFDL'...
# remote: Enumerating objects: 464, done.
# remote: Counting objects: 100% (29/29), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 464 (delta 19), reused 5 (delta 4), pack-reused 435 (from 2)
# Receiving objects: 100% (464/464), 97.79 MiB | 12.61 MiB/s, done.
# Resolving deltas: 100% (161/161), done.
# Updating files: 100% (187/187), done.
# /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL
# Looking in indexes: https://download.pytorch.org/whl/cu121
# ...

# %%
# %cd /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL
# !mkdir -p weights/HRNet
# !mkdir -p weights/NLCDetection
# Out:
# /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL

# %%
import os

zip_path = "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/CASIA2.zip"

local_destination = "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/data_dir"

if os.path.exists(zip_path):
    print("Found the zip file!")
    # !unzip -q "{zip_path}" -d {local_destination}
    print(f"Unzipped to {local_destination}")
else:
    print("Cannot find the zip..")
# Out:
# Found the zip file!
# Unzipped to /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/data_dir

# %%
import shutil

# !rm -rf "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/weights"

zip_path = "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/weights.zip"
local_destination = "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL"

if os.path.exists(zip_path):
    print("Found the zip file!")
    # !unzip -q "{zip_path}" -d {local_destination}
    print(f"Unzipped to {local_destination}")
else:
    print("Cannot find the zip. Double-check if you added the 'Data Analytics' folder shortcut to 'My Drive'.")

print("\nFinal Weight Structure:")
# !ls -R /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/weights
# Out:
# Found the zip file!
# Unzipped to /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL
#
# Final Weight Structure:
# HRNet        NLCDetection
#
# /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/weights/HRNet:
# 750001.pth
#
# /Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/weights/NLCDetection:
# 750001.pth

# %%
import shutil

data_dir = '/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/data_dir'


for item in os.listdir(data_dir):
    item_path = os.path.join(data_dir, item)

    if item != 'CASIA2' :
        try:
            if os.path.isdir(item_path):
                shutil.rmtree(item_path) 
                print(f"Deleted folder: {item}")
            else:
                os.remove(item_path)     
                print(f"Deleted file: {item}")
        except Exception as e:
            print(f"Could not delete {item}: {e}")

print("\n Cleanup finished. Only 'CASIA2' remains.")
# Out:
# Deleted folder: NIST16
# Deleted folder: columbia
# Deleted folder: __MACOSX
# Deleted folder: IMD2020
# Deleted folder: Coverage
# Deleted folder: CASIA
#
#  Cleanup finished. Only 'CASIA2' remains.

# %%
# !python HiFi_Net_loc.py --val_tag 0 --val_all 1 --ablation full
# Out:
# Traceback (most recent call last):
#   File "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/HiFi_Net_loc.py", line 213, in <module>
#     main(args)
#   File "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/HiFi_Net_loc.py", line 142, in main
#     args, writer, FENet, SegNet, FENet_dir, SegNet_dir = config(args)
#                                                          ^^^^^^^^^^^^
#   File "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/HiFi_Net_loc.py", line 45, in config
#     FENet  = get_seg_model(FENet_cfg).to(device) # load the pre-trained model inside.
#              ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/models/seg_hrnet.py", line 570, in get_seg_model
#     model.init_weights(cfg.PRETRAINED)
#   File "/Users/skanderznaidi/Desktop/TUM/Data_Analytics/HiFi_IFDL/models/seg_hrnet.py", line 538, in init_weights
#     pretrained_dict = torch.load(pretrained)
# ...
